# %% [markdown]
# I used pycaret to find the best model to prEdict health insurance owners who will be interested in vihecle insurance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (381109, 12)

# %%
test.shape
# Out:
# (127037, 11)

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
train.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
from pycaret.classification import *

# %%
clf01 = setup(data=train,target='Response')
# Out:
# <style type="text/css">
# #T_103b3_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_103b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_103b3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_103b3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_103b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_103b3_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_103b3_row0_col1" class="data row0 col1" >893</td>
#     </tr>
#     <tr>
#       <th id="T_103b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_103b3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_103b3_row1_col1" class="data row1 col1" >Response</td>
#     </tr>
#     <tr>
#       <th id="T_103b3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_0af67 th {
#   text-align: left;
# }
# ...

# %%
print(best_model)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=893, solver='auto',
#                 tol=0.001)

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_faf20_row10_col0, #T_faf20_row10_col1, #T_faf20_row10_col2, #T_faf20_row10_col3, #T_faf20_row10_col4, #T_faf20_row10_col5, #T_faf20_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_faf20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faf20_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_faf20_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_faf20_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_faf20_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_faf20_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_faf20_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_faf20_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_82d90_row10_col0, #T_82d90_row10_col1, #T_82d90_row10_col2, #T_82d90_row10_col3, #T_82d90_row10_col4, #T_82d90_row10_col5, #T_82d90_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_82d90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82d90_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_82d90_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_82d90_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_82d90_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_82d90_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_82d90_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_82d90_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_c19af_row10_col0, #T_c19af_row10_col1, #T_c19af_row10_col2, #T_c19af_row10_col3, #T_c19af_row10_col4, #T_c19af_row10_col5, #T_c19af_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c19af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c19af_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c19af_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c19af_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c19af_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c19af_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c19af_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c19af_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned = tune_model(lr)
# Out:
# <style type="text/css">
# #T_bdcc8_row10_col0, #T_bdcc8_row10_col1, #T_bdcc8_row10_col2, #T_bdcc8_row10_col3, #T_bdcc8_row10_col4, #T_bdcc8_row10_col5, #T_bdcc8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bdcc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdcc8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bdcc8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bdcc8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bdcc8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bdcc8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bdcc8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bdcc8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned1 = tune_model(rf)
# Out:
# <style type="text/css">
# #T_2f891_row10_col0, #T_2f891_row10_col1, #T_2f891_row10_col2, #T_2f891_row10_col3, #T_2f891_row10_col4, #T_2f891_row10_col5, #T_2f891_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2f891">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f891_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2f891_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2f891_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2f891_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2f891_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2f891_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2f891_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned2 = tune_model(dt)
# Out:
# <style type="text/css">
# #T_0701e_row10_col0, #T_0701e_row10_col1, #T_0701e_row10_col2, #T_0701e_row10_col3, #T_0701e_row10_col4, #T_0701e_row10_col5, #T_0701e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0701e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0701e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0701e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0701e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0701e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0701e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0701e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0701e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tst_prd = predict_model(tuned,data=test)

# %%
tst_prd.to_csv('answer1.csv',index=False)
